# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; no timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 1.7832050323486328 seconds.
# Csv file size 14.155486 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask
dask.config.set({'dataframe.query-planning': True})
import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 0.8186459541320801 seconds.
# Parquet file size 5.517751 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\TazeenQ\AppData\Local\Temp\ipykernel_19688\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.930998   35.061652   34.695816
# A      2013-12-03 00:00:00-05:00   34.571688   34.735011   34.336506
# A      2013-12-04 00:00:00-05:00   34.519425   35.166176   34.441033
# A      2013-12-05 00:00:00-05:00   34.852604   35.146580   34.702349
# A      2013-12-06 00:00:00-05:00   35.120456   35.884793   35.120456
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002213  128.760851  126.770665
# YUM    2024-01-29 00:00:00-05:00  127.194332  128.622925  126.396276
# YUM    2024-01-30 00:00:00-05:00  128.435707  129.283013  127.667222
# YUM    2024-01-31 00:00:00-05:00  129.509627  130.031802  127.351952
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.761143  2039962        0.0           0.0  2013          NaN
# A        34.578220  3462706        0.0           0.0  2013    34.761143
# A        35.002853  3377288        0.0           0.0  2013    34.578220
# A        34.950596  2530939        0.0           0.0  2013    35.002853
# A        35.819466  4268513        0.0           0.0  2013    34.950596
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.297791  1871700        0.0           0.0  2024   127.529312
# YUM     127.184464  1157000        0.0           0.0  2024   128.297791
# YUM     128.622925  1482100        0.0           0.0  2024   127.184464
# YUM     128.691864  1421500        0.0           0.0  2024   128.622925
# YUM     127.578568  2154200        0.0           0.0  2024   128.691864
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-11-07 19:43:56,218, data_manager.py, 45, INFO, Getting price data for all tickers.
# 2024-11-07 19:43:56,218, data_manager.py, 45, INFO, Getting price data for all tickers.
# 2024-11-07 19:43:56,220, data_manager.py, 54, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-11-07 19:43:56,220, data_manager.py, 54, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-11-07 19:43:56,228, data_manager.py, 60, INFO, Processing all tickers
# 2024-11-07 19:43:56,228, data_manager.py, 60, INFO, Processing all tickers
# 2024-11-07 19:43:56,231, data_manager.py, 75, INFO, Processing ticker MMM
# 2024-11-07 19:43:56,231, data_manager.py, 75, INFO, Processing ticker MMM
# 2024-11-07 19:43:56,232, data_manager.py, 111, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-11-07
# 2024-11-07 19:43:56,232, data_manager.py, 111, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:43:56,699, data_manager.py, 85, INFO, Saving data for MMM by year
# 2024-11-07 19:43:56,699, data_manager.py, 85, INFO, Saving data for MMM by year
# 2024-11-07 19:43:58,199, data_manager.py, 75, INFO, Processing ticker AOS
# 2024-11-07 19:43:58,199, data_manager.py, 75, INFO, Processing ticker AOS
# 2024-11-07 19:43:58,201, data_manager.py, 111, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-11-07
# 2024-11-07 19:43:58,201, data_manager.py, 111, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:43:58,546, data_manager.py, 85, INFO, Saving data for AOS by year
# 2024-11-07 19:43:58,546, data_manager.py, 85, INFO, Saving data for AOS by year
# 2024-11-07 19:44:00,292, data_manager.py, 75, INFO, Processing ticker ABT
# 2024-11-07 19:44:00,292, data_manager.py, 75, INFO, Processing ticker ABT
# 2024-11-07 19:44:00,294, data_manager.py, 111, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:00,294, data_manager.py, 111, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:00,645, data_manager.py, 85, INFO, Saving data for ABT by year
# 2024-11-07 19:44:00,645, data_manager.py, 85, INFO, Saving data for ABT by year
# 2024-11-07 19:44:02,159, data_manager.py, 75, INFO, Processing ticker ABBV
# 2024-11-07 19:44:02,159, data_manager.py, 75, INFO, Processing ticker ABBV
# 2024-11-07 19:44:02,161, data_manager.py, 111, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:02,161, data_manager.py, 111, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:02,378, data_manager.py, 85, INFO, Saving data for ABBV by year
# 2024-11-07 19:44:02,378, data_manager.py, 85, INFO, Saving data for ABBV by year
# 2024-11-07 19:44:03,092, data_manager.py, 75, INFO, Processing ticker ACN
# 2024-11-07 19:44:03,092, data_manager.py, 75, INFO, Processing ticker ACN
# 2024-11-07 19:44:03,093, data_manager.py, 111, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:03,093, data_manager.py, 111, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:03,375, data_manager.py, 85, INFO, Saving data for ACN by year
# 2024-11-07 19:44:03,375, data_manager.py, 85, INFO, Saving data for ACN by year
# 2024-11-07 19:44:04,839, data_manager.py, 75, INFO, Processing ticker ADBE
# 2024-11-07 19:44:04,839, data_manager.py, 75, INFO, Processing ticker ADBE
# 2024-11-07 19:44:04,841, data_manager.py, 111, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:04,841, data_manager.py, 111, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:05,189, data_manager.py, 85, INFO, Saving data for ADBE by year
# 2024-11-07 19:44:05,189, data_manager.py, 85, INFO, Saving data for ADBE by year
# 2024-11-07 19:44:06,805, data_manager.py, 75, INFO, Processing ticker AMD
# 2024-11-07 19:44:06,805, data_manager.py, 75, INFO, Processing ticker AMD
# 2024-11-07 19:44:06,807, data_manager.py, 111, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:06,807, data_manager.py, 111, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:07,092, data_manager.py, 85, INFO, Saving data for AMD by year
# 2024-11-07 19:44:07,092, data_manager.py, 85, INFO, Saving data for AMD by year
# 2024-11-07 19:44:08,651, data_manager.py, 75, INFO, Processing ticker AES
# 2024-11-07 19:44:08,651, data_manager.py, 75, INFO, Processing ticker AES
# 2024-11-07 19:44:08,654, data_manager.py, 111, INFO, Getting stock price data for AES from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:08,654, data_manager.py, 111, INFO, Getting stock price data for AES from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:09,002, data_manager.py, 85, INFO, Saving data for AES by year
# 2024-11-07 19:44:09,002, data_manager.py, 85, INFO, Saving data for AES by year
# 2024-11-07 19:44:10,566, data_manager.py, 75, INFO, Processing ticker AFL
# 2024-11-07 19:44:10,566, data_manager.py, 75, INFO, Processing ticker AFL
# 2024-11-07 19:44:10,567, data_manager.py, 111, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:10,567, data_manager.py, 111, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:10,956, data_manager.py, 85, INFO, Saving data for AFL by year
# 2024-11-07 19:44:10,956, data_manager.py, 85, INFO, Saving data for AFL by year
# 2024-11-07 19:44:12,435, data_manager.py, 75, INFO, Processing ticker A
# 2024-11-07 19:44:12,435, data_manager.py, 75, INFO, Processing ticker A
# 2024-11-07 19:44:12,439, data_manager.py, 111, INFO, Getting stock price data for A from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:12,439, data_manager.py, 111, INFO, Getting stock price data for A from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:12,813, data_manager.py, 85, INFO, Saving data for A by year
# 2024-11-07 19:44:12,813, data_manager.py, 85, INFO, Saving data for A by year
# 2024-11-07 19:44:14,312, data_manager.py, 75, INFO, Processing ticker APD
# 2024-11-07 19:44:14,312, data_manager.py, 75, INFO, Processing ticker APD
# 2024-11-07 19:44:14,313, data_manager.py, 111, INFO, Getting stock price data for APD from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:14,313, data_manager.py, 111, INFO, Getting stock price data for APD from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:14,654, data_manager.py, 85, INFO, Saving data for APD by year
# 2024-11-07 19:44:14,654, data_manager.py, 85, INFO, Saving data for APD by year
# 2024-11-07 19:44:16,179, data_manager.py, 75, INFO, Processing ticker ABNB
# 2024-11-07 19:44:16,179, data_manager.py, 75, INFO, Processing ticker ABNB
# 2024-11-07 19:44:16,181, data_manager.py, 111, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:16,181, data_manager.py, 111, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:16,335, data_manager.py, 85, INFO, Saving data for ABNB by year
# 2024-11-07 19:44:16,335, data_manager.py, 85, INFO, Saving data for ABNB by year
# 2024-11-07 19:44:16,705, data_manager.py, 75, INFO, Processing ticker AKAM
# 2024-11-07 19:44:16,705, data_manager.py, 75, INFO, Processing ticker AKAM
# 2024-11-07 19:44:16,707, data_manager.py, 111, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:16,707, data_manager.py, 111, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:16,963, data_manager.py, 85, INFO, Saving data for AKAM by year
# 2024-11-07 19:44:16,963, data_manager.py, 85, INFO, Saving data for AKAM by year
# 2024-11-07 19:44:18,434, data_manager.py, 75, INFO, Processing ticker ALB
# 2024-11-07 19:44:18,434, data_manager.py, 75, INFO, Processing ticker ALB
# 2024-11-07 19:44:18,435, data_manager.py, 111, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:18,435, data_manager.py, 111, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:18,761, data_manager.py, 85, INFO, Saving data for ALB by year
# 2024-11-07 19:44:18,761, data_manager.py, 85, INFO, Saving data for ALB by year
# 2024-11-07 19:44:20,320, data_manager.py, 75, INFO, Processing ticker ARE
# 2024-11-07 19:44:20,320, data_manager.py, 75, INFO, Processing ticker ARE
# 2024-11-07 19:44:20,322, data_manager.py, 111, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:20,322, data_manager.py, 111, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:20,630, data_manager.py, 85, INFO, Saving data for ARE by year
# 2024-11-07 19:44:20,630, data_manager.py, 85, INFO, Saving data for ARE by year
# 2024-11-07 19:44:22,322, data_manager.py, 75, INFO, Processing ticker ALGN
# 2024-11-07 19:44:22,322, data_manager.py, 75, INFO, Processing ticker ALGN
# 2024-11-07 19:44:22,326, data_manager.py, 111, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:22,326, data_manager.py, 111, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:22,580, data_manager.py, 85, INFO, Saving data for ALGN by year
# 2024-11-07 19:44:22,580, data_manager.py, 85, INFO, Saving data for ALGN by year
# 2024-11-07 19:44:24,191, data_manager.py, 75, INFO, Processing ticker ALLE
# 2024-11-07 19:44:24,191, data_manager.py, 75, INFO, Processing ticker ALLE
# 2024-11-07 19:44:24,193, data_manager.py, 111, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:24,193, data_manager.py, 111, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:24,431, data_manager.py, 85, INFO, Saving data for ALLE by year
# 2024-11-07 19:44:24,431, data_manager.py, 85, INFO, Saving data for ALLE by year
# 2024-11-07 19:44:25,291, data_manager.py, 75, INFO, Processing ticker LNT
# 2024-11-07 19:44:25,291, data_manager.py, 75, INFO, Processing ticker LNT
# 2024-11-07 19:44:25,292, data_manager.py, 111, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:25,292, data_manager.py, 111, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:25,655, data_manager.py, 85, INFO, Saving data for LNT by year
# 2024-11-07 19:44:25,655, data_manager.py, 85, INFO, Saving data for LNT by year
# 2024-11-07 19:44:27,337, data_manager.py, 75, INFO, Processing ticker ALL
# 2024-11-07 19:44:27,337, data_manager.py, 75, INFO, Processing ticker ALL
# 2024-11-07 19:44:27,339, data_manager.py, 111, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:27,339, data_manager.py, 111, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:27,660, data_manager.py, 85, INFO, Saving data for ALL by year
# 2024-11-07 19:44:27,660, data_manager.py, 85, INFO, Saving data for ALL by year
# 2024-11-07 19:44:29,456, data_manager.py, 75, INFO, Processing ticker GOOGL
# 2024-11-07 19:44:29,456, data_manager.py, 75, INFO, Processing ticker GOOGL
# 2024-11-07 19:44:29,458, data_manager.py, 111, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:29,458, data_manager.py, 111, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:29,807, data_manager.py, 85, INFO, Saving data for GOOGL by year
# 2024-11-07 19:44:29,807, data_manager.py, 85, INFO, Saving data for GOOGL by year
# 2024-11-07 19:44:31,361, data_manager.py, 75, INFO, Processing ticker GOOG
# 2024-11-07 19:44:31,361, data_manager.py, 75, INFO, Processing ticker GOOG
# 2024-11-07 19:44:31,362, data_manager.py, 111, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:31,362, data_manager.py, 111, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:31,698, data_manager.py, 85, INFO, Saving data for GOOG by year
# 2024-11-07 19:44:31,698, data_manager.py, 85, INFO, Saving data for GOOG by year
# 2024-11-07 19:44:33,245, data_manager.py, 75, INFO, Processing ticker MO
# 2024-11-07 19:44:33,245, data_manager.py, 75, INFO, Processing ticker MO
# 2024-11-07 19:44:33,246, data_manager.py, 111, INFO, Getting stock price data for MO from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:33,246, data_manager.py, 111, INFO, Getting stock price data for MO from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:33,593, data_manager.py, 85, INFO, Saving data for MO by year
# 2024-11-07 19:44:33,593, data_manager.py, 85, INFO, Saving data for MO by year
# 2024-11-07 19:44:35,222, data_manager.py, 75, INFO, Processing ticker AMZN
# 2024-11-07 19:44:35,222, data_manager.py, 75, INFO, Processing ticker AMZN
# 2024-11-07 19:44:35,224, data_manager.py, 111, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:35,224, data_manager.py, 111, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:35,511, data_manager.py, 85, INFO, Saving data for AMZN by year
# 2024-11-07 19:44:35,511, data_manager.py, 85, INFO, Saving data for AMZN by year
# 2024-11-07 19:44:37,246, data_manager.py, 75, INFO, Processing ticker AMCR
# 2024-11-07 19:44:37,246, data_manager.py, 75, INFO, Processing ticker AMCR
# 2024-11-07 19:44:37,249, data_manager.py, 111, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:37,249, data_manager.py, 111, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:37,466, data_manager.py, 85, INFO, Saving data for AMCR by year
# 2024-11-07 19:44:37,466, data_manager.py, 85, INFO, Saving data for AMCR by year
# 2024-11-07 19:44:38,329, data_manager.py, 75, INFO, Processing ticker AEE
# 2024-11-07 19:44:38,329, data_manager.py, 75, INFO, Processing ticker AEE
# 2024-11-07 19:44:38,330, data_manager.py, 111, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:38,330, data_manager.py, 111, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:38,645, data_manager.py, 85, INFO, Saving data for AEE by year
# 2024-11-07 19:44:38,645, data_manager.py, 85, INFO, Saving data for AEE by year
# 2024-11-07 19:44:40,300, data_manager.py, 75, INFO, Processing ticker AAL
# 2024-11-07 19:44:40,300, data_manager.py, 75, INFO, Processing ticker AAL
# 2024-11-07 19:44:40,302, data_manager.py, 111, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:40,302, data_manager.py, 111, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:40,561, data_manager.py, 85, INFO, Saving data for AAL by year
# 2024-11-07 19:44:40,561, data_manager.py, 85, INFO, Saving data for AAL by year
# 2024-11-07 19:44:41,956, data_manager.py, 75, INFO, Processing ticker AEP
# 2024-11-07 19:44:41,956, data_manager.py, 75, INFO, Processing ticker AEP
# 2024-11-07 19:44:41,957, data_manager.py, 111, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:41,957, data_manager.py, 111, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:42,387, data_manager.py, 85, INFO, Saving data for AEP by year
# 2024-11-07 19:44:42,387, data_manager.py, 85, INFO, Saving data for AEP by year
# 2024-11-07 19:44:44,004, data_manager.py, 75, INFO, Processing ticker AXP
# 2024-11-07 19:44:44,004, data_manager.py, 75, INFO, Processing ticker AXP
# 2024-11-07 19:44:44,005, data_manager.py, 111, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:44,005, data_manager.py, 111, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:44,377, data_manager.py, 85, INFO, Saving data for AXP by year
# 2024-11-07 19:44:44,377, data_manager.py, 85, INFO, Saving data for AXP by year
# 2024-11-07 19:44:45,979, data_manager.py, 75, INFO, Processing ticker AIG
# 2024-11-07 19:44:45,979, data_manager.py, 75, INFO, Processing ticker AIG
# 2024-11-07 19:44:45,982, data_manager.py, 111, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:45,982, data_manager.py, 111, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:46,335, data_manager.py, 85, INFO, Saving data for AIG by year
# 2024-11-07 19:44:46,335, data_manager.py, 85, INFO, Saving data for AIG by year
# 2024-11-07 19:44:48,087, data_manager.py, 75, INFO, Processing ticker AMT
# 2024-11-07 19:44:48,087, data_manager.py, 75, INFO, Processing ticker AMT
# 2024-11-07 19:44:48,089, data_manager.py, 111, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:48,089, data_manager.py, 111, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:48,479, data_manager.py, 85, INFO, Saving data for AMT by year
# 2024-11-07 19:44:48,479, data_manager.py, 85, INFO, Saving data for AMT by year
# 2024-11-07 19:44:50,261, data_manager.py, 75, INFO, Processing ticker AWK
# 2024-11-07 19:44:50,261, data_manager.py, 75, INFO, Processing ticker AWK
# 2024-11-07 19:44:50,263, data_manager.py, 111, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:50,263, data_manager.py, 111, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:50,522, data_manager.py, 85, INFO, Saving data for AWK by year
# 2024-11-07 19:44:50,522, data_manager.py, 85, INFO, Saving data for AWK by year
# 2024-11-07 19:44:51,631, data_manager.py, 75, INFO, Processing ticker AMP
# 2024-11-07 19:44:51,631, data_manager.py, 75, INFO, Processing ticker AMP
# 2024-11-07 19:44:51,633, data_manager.py, 111, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:51,633, data_manager.py, 111, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:51,912, data_manager.py, 85, INFO, Saving data for AMP by year
# 2024-11-07 19:44:51,912, data_manager.py, 85, INFO, Saving data for AMP by year
# 2024-11-07 19:44:53,247, data_manager.py, 75, INFO, Processing ticker AME
# 2024-11-07 19:44:53,247, data_manager.py, 75, INFO, Processing ticker AME
# 2024-11-07 19:44:53,249, data_manager.py, 111, INFO, Getting stock price data for AME from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:53,249, data_manager.py, 111, INFO, Getting stock price data for AME from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:53,622, data_manager.py, 85, INFO, Saving data for AME by year
# 2024-11-07 19:44:53,622, data_manager.py, 85, INFO, Saving data for AME by year
# 2024-11-07 19:44:55,327, data_manager.py, 75, INFO, Processing ticker AMGN
# 2024-11-07 19:44:55,327, data_manager.py, 75, INFO, Processing ticker AMGN
# 2024-11-07 19:44:55,329, data_manager.py, 111, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:55,329, data_manager.py, 111, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:55,669, data_manager.py, 85, INFO, Saving data for AMGN by year
# 2024-11-07 19:44:55,669, data_manager.py, 85, INFO, Saving data for AMGN by year
# 2024-11-07 19:44:57,527, data_manager.py, 75, INFO, Processing ticker APH
# 2024-11-07 19:44:57,527, data_manager.py, 75, INFO, Processing ticker APH
# 2024-11-07 19:44:57,528, data_manager.py, 111, INFO, Getting stock price data for APH from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:57,528, data_manager.py, 111, INFO, Getting stock price data for APH from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:57,851, data_manager.py, 85, INFO, Saving data for APH by year
# 2024-11-07 19:44:57,851, data_manager.py, 85, INFO, Saving data for APH by year
# 2024-11-07 19:44:59,507, data_manager.py, 75, INFO, Processing ticker ADI
# 2024-11-07 19:44:59,507, data_manager.py, 75, INFO, Processing ticker ADI
# 2024-11-07 19:44:59,508, data_manager.py, 111, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-11-07
# 2024-11-07 19:44:59,508, data_manager.py, 111, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:44:59,879, data_manager.py, 85, INFO, Saving data for ADI by year
# 2024-11-07 19:44:59,879, data_manager.py, 85, INFO, Saving data for ADI by year
# 2024-11-07 19:45:01,545, data_manager.py, 75, INFO, Processing ticker ANSS
# 2024-11-07 19:45:01,545, data_manager.py, 75, INFO, Processing ticker ANSS
# 2024-11-07 19:45:01,547, data_manager.py, 111, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:01,547, data_manager.py, 111, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:01,895, data_manager.py, 85, INFO, Saving data for ANSS by year
# 2024-11-07 19:45:01,895, data_manager.py, 85, INFO, Saving data for ANSS by year
# 2024-11-07 19:45:03,628, data_manager.py, 75, INFO, Processing ticker AON
# 2024-11-07 19:45:03,628, data_manager.py, 75, INFO, Processing ticker AON
# 2024-11-07 19:45:03,629, data_manager.py, 111, INFO, Getting stock price data for AON from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:03,629, data_manager.py, 111, INFO, Getting stock price data for AON from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:03,971, data_manager.py, 85, INFO, Saving data for AON by year
# 2024-11-07 19:45:03,971, data_manager.py, 85, INFO, Saving data for AON by year
# 2024-11-07 19:45:05,706, data_manager.py, 75, INFO, Processing ticker APA
# 2024-11-07 19:45:05,706, data_manager.py, 75, INFO, Processing ticker APA
# 2024-11-07 19:45:05,707, data_manager.py, 111, INFO, Getting stock price data for APA from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:05,707, data_manager.py, 111, INFO, Getting stock price data for APA from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:06,137, data_manager.py, 85, INFO, Saving data for APA by year
# 2024-11-07 19:45:06,137, data_manager.py, 85, INFO, Saving data for APA by year
# 2024-11-07 19:45:07,852, data_manager.py, 75, INFO, Processing ticker AAPL
# 2024-11-07 19:45:07,852, data_manager.py, 75, INFO, Processing ticker AAPL
# 2024-11-07 19:45:07,854, data_manager.py, 111, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:07,854, data_manager.py, 111, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:08,279, data_manager.py, 85, INFO, Saving data for AAPL by year
# 2024-11-07 19:45:08,279, data_manager.py, 85, INFO, Saving data for AAPL by year
# 2024-11-07 19:45:09,917, data_manager.py, 75, INFO, Processing ticker AMAT
# 2024-11-07 19:45:09,917, data_manager.py, 75, INFO, Processing ticker AMAT
# 2024-11-07 19:45:09,918, data_manager.py, 111, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:09,918, data_manager.py, 111, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:10,241, data_manager.py, 85, INFO, Saving data for AMAT by year
# 2024-11-07 19:45:10,241, data_manager.py, 85, INFO, Saving data for AMAT by year
# 2024-11-07 19:45:11,869, data_manager.py, 75, INFO, Processing ticker APTV
# 2024-11-07 19:45:11,869, data_manager.py, 75, INFO, Processing ticker APTV
# 2024-11-07 19:45:11,871, data_manager.py, 111, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:11,871, data_manager.py, 111, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:12,129, data_manager.py, 85, INFO, Saving data for APTV by year
# 2024-11-07 19:45:12,129, data_manager.py, 85, INFO, Saving data for APTV by year
# 2024-11-07 19:45:13,038, data_manager.py, 75, INFO, Processing ticker ACGL
# 2024-11-07 19:45:13,038, data_manager.py, 75, INFO, Processing ticker ACGL
# 2024-11-07 19:45:13,040, data_manager.py, 111, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:13,040, data_manager.py, 111, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:13,317, data_manager.py, 85, INFO, Saving data for ACGL by year
# 2024-11-07 19:45:13,317, data_manager.py, 85, INFO, Saving data for ACGL by year
# 2024-11-07 19:45:14,987, data_manager.py, 75, INFO, Processing ticker ADM
# 2024-11-07 19:45:14,987, data_manager.py, 75, INFO, Processing ticker ADM
# 2024-11-07 19:45:14,989, data_manager.py, 111, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:14,989, data_manager.py, 111, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:15,330, data_manager.py, 85, INFO, Saving data for ADM by year
# 2024-11-07 19:45:15,330, data_manager.py, 85, INFO, Saving data for ADM by year
# 2024-11-07 19:45:16,951, data_manager.py, 75, INFO, Processing ticker ANET
# 2024-11-07 19:45:16,951, data_manager.py, 75, INFO, Processing ticker ANET
# 2024-11-07 19:45:16,953, data_manager.py, 111, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:16,953, data_manager.py, 111, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:17,179, data_manager.py, 85, INFO, Saving data for ANET by year
# 2024-11-07 19:45:17,179, data_manager.py, 85, INFO, Saving data for ANET by year
# 2024-11-07 19:45:18,028, data_manager.py, 75, INFO, Processing ticker AJG
# 2024-11-07 19:45:18,028, data_manager.py, 75, INFO, Processing ticker AJG
# 2024-11-07 19:45:18,029, data_manager.py, 111, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:18,029, data_manager.py, 111, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:18,374, data_manager.py, 85, INFO, Saving data for AJG by year
# 2024-11-07 19:45:18,374, data_manager.py, 85, INFO, Saving data for AJG by year
# 2024-11-07 19:45:20,447, data_manager.py, 75, INFO, Processing ticker AIZ
# 2024-11-07 19:45:20,447, data_manager.py, 75, INFO, Processing ticker AIZ
# 2024-11-07 19:45:20,447, data_manager.py, 111, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:20,447, data_manager.py, 111, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:20,770, data_manager.py, 85, INFO, Saving data for AIZ by year
# 2024-11-07 19:45:20,770, data_manager.py, 85, INFO, Saving data for AIZ by year
# 2024-11-07 19:45:22,768, data_manager.py, 75, INFO, Processing ticker T
# 2024-11-07 19:45:22,768, data_manager.py, 75, INFO, Processing ticker T
# 2024-11-07 19:45:22,769, data_manager.py, 111, INFO, Getting stock price data for T from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:22,769, data_manager.py, 111, INFO, Getting stock price data for T from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:23,121, data_manager.py, 85, INFO, Saving data for T by year
# 2024-11-07 19:45:23,121, data_manager.py, 85, INFO, Saving data for T by year
# 2024-11-07 19:45:25,015, data_manager.py, 75, INFO, Processing ticker ATO
# 2024-11-07 19:45:25,015, data_manager.py, 75, INFO, Processing ticker ATO
# 2024-11-07 19:45:25,017, data_manager.py, 111, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:25,017, data_manager.py, 111, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:25,344, data_manager.py, 85, INFO, Saving data for ATO by year
# 2024-11-07 19:45:25,344, data_manager.py, 85, INFO, Saving data for ATO by year
# 2024-11-07 19:45:27,598, data_manager.py, 75, INFO, Processing ticker ADSK
# 2024-11-07 19:45:27,598, data_manager.py, 75, INFO, Processing ticker ADSK
# 2024-11-07 19:45:27,601, data_manager.py, 111, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:27,601, data_manager.py, 111, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:27,963, data_manager.py, 85, INFO, Saving data for ADSK by year
# 2024-11-07 19:45:27,963, data_manager.py, 85, INFO, Saving data for ADSK by year
# 2024-11-07 19:45:29,983, data_manager.py, 75, INFO, Processing ticker ADP
# 2024-11-07 19:45:29,983, data_manager.py, 75, INFO, Processing ticker ADP
# 2024-11-07 19:45:29,985, data_manager.py, 111, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:29,985, data_manager.py, 111, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:30,470, data_manager.py, 85, INFO, Saving data for ADP by year
# 2024-11-07 19:45:30,470, data_manager.py, 85, INFO, Saving data for ADP by year
# 2024-11-07 19:45:32,514, data_manager.py, 75, INFO, Processing ticker AZO
# 2024-11-07 19:45:32,514, data_manager.py, 75, INFO, Processing ticker AZO
# 2024-11-07 19:45:32,517, data_manager.py, 111, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:32,517, data_manager.py, 111, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:32,784, data_manager.py, 85, INFO, Saving data for AZO by year
# 2024-11-07 19:45:32,784, data_manager.py, 85, INFO, Saving data for AZO by year
# 2024-11-07 19:45:34,695, data_manager.py, 75, INFO, Processing ticker AVB
# 2024-11-07 19:45:34,695, data_manager.py, 75, INFO, Processing ticker AVB
# 2024-11-07 19:45:34,697, data_manager.py, 111, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:34,697, data_manager.py, 111, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:35,001, data_manager.py, 85, INFO, Saving data for AVB by year
# 2024-11-07 19:45:35,001, data_manager.py, 85, INFO, Saving data for AVB by year
# 2024-11-07 19:45:36,763, data_manager.py, 75, INFO, Processing ticker AVY
# 2024-11-07 19:45:36,763, data_manager.py, 75, INFO, Processing ticker AVY
# 2024-11-07 19:45:36,766, data_manager.py, 111, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:36,766, data_manager.py, 111, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:37,099, data_manager.py, 85, INFO, Saving data for AVY by year
# 2024-11-07 19:45:37,099, data_manager.py, 85, INFO, Saving data for AVY by year
# 2024-11-07 19:45:38,859, data_manager.py, 75, INFO, Processing ticker AXON
# 2024-11-07 19:45:38,859, data_manager.py, 75, INFO, Processing ticker AXON
# 2024-11-07 19:45:38,861, data_manager.py, 111, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:38,861, data_manager.py, 111, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:39,130, data_manager.py, 85, INFO, Saving data for AXON by year
# 2024-11-07 19:45:39,130, data_manager.py, 85, INFO, Saving data for AXON by year
# 2024-11-07 19:45:41,154, data_manager.py, 75, INFO, Processing ticker BKR
# 2024-11-07 19:45:41,154, data_manager.py, 75, INFO, Processing ticker BKR
# 2024-11-07 19:45:41,155, data_manager.py, 111, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:41,155, data_manager.py, 111, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:41,548, data_manager.py, 85, INFO, Saving data for BKR by year
# 2024-11-07 19:45:41,548, data_manager.py, 85, INFO, Saving data for BKR by year
# 2024-11-07 19:45:44,143, data_manager.py, 75, INFO, Processing ticker BALL
# 2024-11-07 19:45:44,143, data_manager.py, 75, INFO, Processing ticker BALL
# 2024-11-07 19:45:44,147, data_manager.py, 111, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:44,147, data_manager.py, 111, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:44,564, data_manager.py, 85, INFO, Saving data for BALL by year
# 2024-11-07 19:45:44,564, data_manager.py, 85, INFO, Saving data for BALL by year
# 2024-11-07 19:45:46,401, data_manager.py, 75, INFO, Processing ticker BAC
# 2024-11-07 19:45:46,401, data_manager.py, 75, INFO, Processing ticker BAC
# 2024-11-07 19:45:46,403, data_manager.py, 111, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:46,403, data_manager.py, 111, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:46,727, data_manager.py, 85, INFO, Saving data for BAC by year
# 2024-11-07 19:45:46,727, data_manager.py, 85, INFO, Saving data for BAC by year
# 2024-11-07 19:45:48,432, data_manager.py, 75, INFO, Processing ticker BK
# 2024-11-07 19:45:48,432, data_manager.py, 75, INFO, Processing ticker BK
# 2024-11-07 19:45:48,434, data_manager.py, 111, INFO, Getting stock price data for BK from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:48,434, data_manager.py, 111, INFO, Getting stock price data for BK from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:48,774, data_manager.py, 85, INFO, Saving data for BK by year
# 2024-11-07 19:45:48,774, data_manager.py, 85, INFO, Saving data for BK by year
# 2024-11-07 19:45:50,529, data_manager.py, 75, INFO, Processing ticker BBWI
# 2024-11-07 19:45:50,529, data_manager.py, 75, INFO, Processing ticker BBWI
# 2024-11-07 19:45:50,532, data_manager.py, 111, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:50,532, data_manager.py, 111, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:50,910, data_manager.py, 85, INFO, Saving data for BBWI by year
# 2024-11-07 19:45:50,910, data_manager.py, 85, INFO, Saving data for BBWI by year
# 2024-11-07 19:45:52,663, data_manager.py, 75, INFO, Processing ticker BAX
# 2024-11-07 19:45:52,663, data_manager.py, 75, INFO, Processing ticker BAX
# 2024-11-07 19:45:52,665, data_manager.py, 111, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:52,665, data_manager.py, 111, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:53,047, data_manager.py, 85, INFO, Saving data for BAX by year
# 2024-11-07 19:45:53,047, data_manager.py, 85, INFO, Saving data for BAX by year
# 2024-11-07 19:45:54,864, data_manager.py, 75, INFO, Processing ticker BDX
# 2024-11-07 19:45:54,864, data_manager.py, 75, INFO, Processing ticker BDX
# 2024-11-07 19:45:54,868, data_manager.py, 111, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:54,868, data_manager.py, 111, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:55,251, data_manager.py, 85, INFO, Saving data for BDX by year
# 2024-11-07 19:45:55,251, data_manager.py, 85, INFO, Saving data for BDX by year
# 2024-11-07 19:45:57,228, data_manager.py, 75, INFO, Processing ticker BRK.B
# 2024-11-07 19:45:57,228, data_manager.py, 75, INFO, Processing ticker BRK.B
# 2024-11-07 19:45:57,230, data_manager.py, 111, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:57,230, data_manager.py, 111, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-11-07 19:45:58,792, data_manager.py, 85, INFO, Saving data for BRK.B by year
# 2024-11-07 19:45:58,792, data_manager.py, 85, INFO, Saving data for BRK.B by year
# 2024-11-07 19:45:58,794, data_manager.py, 103, WARNING, No data found for BRK.B
# 2024-11-07 19:45:58,794, data_manager.py, 103, WARNING, No data found for BRK.B
# 2024-11-07 19:45:58,796, data_manager.py, 75, INFO, Processing ticker BBY
# 2024-11-07 19:45:58,796, data_manager.py, 75, INFO, Processing ticker BBY
# 2024-11-07 19:45:58,797, data_manager.py, 111, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-11-07
# 2024-11-07 19:45:58,797, data_manager.py, 111, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:45:59,146, data_manager.py, 85, INFO, Saving data for BBY by year
# 2024-11-07 19:45:59,146, data_manager.py, 85, INFO, Saving data for BBY by year
# 2024-11-07 19:46:01,164, data_manager.py, 75, INFO, Processing ticker BIO
# 2024-11-07 19:46:01,164, data_manager.py, 75, INFO, Processing ticker BIO
# 2024-11-07 19:46:01,166, data_manager.py, 111, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:01,166, data_manager.py, 111, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:01,444, data_manager.py, 85, INFO, Saving data for BIO by year
# 2024-11-07 19:46:01,444, data_manager.py, 85, INFO, Saving data for BIO by year
# 2024-11-07 19:46:03,365, data_manager.py, 75, INFO, Processing ticker TECH
# 2024-11-07 19:46:03,365, data_manager.py, 75, INFO, Processing ticker TECH
# 2024-11-07 19:46:03,368, data_manager.py, 111, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:03,368, data_manager.py, 111, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:03,755, data_manager.py, 85, INFO, Saving data for TECH by year
# 2024-11-07 19:46:03,755, data_manager.py, 85, INFO, Saving data for TECH by year
# 2024-11-07 19:46:06,020, data_manager.py, 75, INFO, Processing ticker BIIB
# 2024-11-07 19:46:06,020, data_manager.py, 75, INFO, Processing ticker BIIB
# 2024-11-07 19:46:06,023, data_manager.py, 111, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:06,023, data_manager.py, 111, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:06,326, data_manager.py, 85, INFO, Saving data for BIIB by year
# 2024-11-07 19:46:06,326, data_manager.py, 85, INFO, Saving data for BIIB by year
# 2024-11-07 19:46:08,616, data_manager.py, 75, INFO, Processing ticker BLK
# 2024-11-07 19:46:08,616, data_manager.py, 75, INFO, Processing ticker BLK
# 2024-11-07 19:46:08,618, data_manager.py, 111, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:08,618, data_manager.py, 111, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:08,917, data_manager.py, 85, INFO, Saving data for BLK by year
# 2024-11-07 19:46:08,917, data_manager.py, 85, INFO, Saving data for BLK by year
# 2024-11-07 19:46:11,111, data_manager.py, 75, INFO, Processing ticker BX
# 2024-11-07 19:46:11,111, data_manager.py, 75, INFO, Processing ticker BX
# 2024-11-07 19:46:11,113, data_manager.py, 111, INFO, Getting stock price data for BX from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:11,113, data_manager.py, 111, INFO, Getting stock price data for BX from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:11,392, data_manager.py, 85, INFO, Saving data for BX by year
# 2024-11-07 19:46:11,392, data_manager.py, 85, INFO, Saving data for BX by year
# 2024-11-07 19:46:13,202, data_manager.py, 75, INFO, Processing ticker BA
# 2024-11-07 19:46:13,202, data_manager.py, 75, INFO, Processing ticker BA
# 2024-11-07 19:46:13,203, data_manager.py, 111, INFO, Getting stock price data for BA from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:13,203, data_manager.py, 111, INFO, Getting stock price data for BA from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:13,523, data_manager.py, 85, INFO, Saving data for BA by year
# 2024-11-07 19:46:13,523, data_manager.py, 85, INFO, Saving data for BA by year
# 2024-11-07 19:46:15,505, data_manager.py, 75, INFO, Processing ticker BKNG
# 2024-11-07 19:46:15,505, data_manager.py, 75, INFO, Processing ticker BKNG
# 2024-11-07 19:46:15,507, data_manager.py, 111, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:15,507, data_manager.py, 111, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:15,795, data_manager.py, 85, INFO, Saving data for BKNG by year
# 2024-11-07 19:46:15,795, data_manager.py, 85, INFO, Saving data for BKNG by year
# 2024-11-07 19:46:18,000, data_manager.py, 75, INFO, Processing ticker BWA
# 2024-11-07 19:46:18,000, data_manager.py, 75, INFO, Processing ticker BWA
# 2024-11-07 19:46:18,001, data_manager.py, 111, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:18,001, data_manager.py, 111, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:18,386, data_manager.py, 85, INFO, Saving data for BWA by year
# 2024-11-07 19:46:18,386, data_manager.py, 85, INFO, Saving data for BWA by year
# 2024-11-07 19:46:20,661, data_manager.py, 75, INFO, Processing ticker BXP
# 2024-11-07 19:46:20,661, data_manager.py, 75, INFO, Processing ticker BXP
# 2024-11-07 19:46:20,664, data_manager.py, 111, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:20,664, data_manager.py, 111, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:21,055, data_manager.py, 85, INFO, Saving data for BXP by year
# 2024-11-07 19:46:21,055, data_manager.py, 85, INFO, Saving data for BXP by year
# 2024-11-07 19:46:23,137, data_manager.py, 75, INFO, Processing ticker BSX
# 2024-11-07 19:46:23,137, data_manager.py, 75, INFO, Processing ticker BSX
# 2024-11-07 19:46:23,138, data_manager.py, 111, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:23,138, data_manager.py, 111, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:23,456, data_manager.py, 85, INFO, Saving data for BSX by year
# 2024-11-07 19:46:23,456, data_manager.py, 85, INFO, Saving data for BSX by year
# 2024-11-07 19:46:25,667, data_manager.py, 75, INFO, Processing ticker BMY
# 2024-11-07 19:46:25,667, data_manager.py, 75, INFO, Processing ticker BMY
# 2024-11-07 19:46:25,668, data_manager.py, 111, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:25,668, data_manager.py, 111, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:26,041, data_manager.py, 85, INFO, Saving data for BMY by year
# 2024-11-07 19:46:26,041, data_manager.py, 85, INFO, Saving data for BMY by year
# 2024-11-07 19:46:28,290, data_manager.py, 75, INFO, Processing ticker AVGO
# 2024-11-07 19:46:28,290, data_manager.py, 75, INFO, Processing ticker AVGO
# 2024-11-07 19:46:28,292, data_manager.py, 111, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:28,292, data_manager.py, 111, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:28,637, data_manager.py, 85, INFO, Saving data for AVGO by year
# 2024-11-07 19:46:28,637, data_manager.py, 85, INFO, Saving data for AVGO by year
# 2024-11-07 19:46:30,142, data_manager.py, 75, INFO, Processing ticker BR
# 2024-11-07 19:46:30,142, data_manager.py, 75, INFO, Processing ticker BR
# 2024-11-07 19:46:30,144, data_manager.py, 111, INFO, Getting stock price data for BR from 2000-01-01 to 2024-11-07
# 2024-11-07 19:46:30,144, data_manager.py, 111, INFO, Getting stock price data for BR from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 19:46:30,405, data_manager.py, 85, INFO, Saving data for BR by year
# 2024-11-07 19:46:30,405, data_manager.py, 85, INFO, Saving data for BR by year
# 2024-11-07 19:46:32,035, data_manager.py, 75, INFO, Processing ticker BRO
# 2024-11-07 19:46:32,035, data_manager.py, 75, INFO, Processing ticker BRO
# ...
# 2024-11-07 20:00:41,208, data_manager.py, 111, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:41,208, data_manager.py, 111, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:41,535, data_manager.py, 85, INFO, Saving data for WAB by year
# 2024-11-07 20:00:41,535, data_manager.py, 85, INFO, Saving data for WAB by year
# 2024-11-07 20:00:43,196, data_manager.py, 75, INFO, Processing ticker WBA
# 2024-11-07 20:00:43,196, data_manager.py, 75, INFO, Processing ticker WBA
# 2024-11-07 20:00:43,201, data_manager.py, 111, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:43,201, data_manager.py, 111, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:43,564, data_manager.py, 85, INFO, Saving data for WBA by year
# 2024-11-07 20:00:43,564, data_manager.py, 85, INFO, Saving data for WBA by year
# 2024-11-07 20:00:45,146, data_manager.py, 75, INFO, Processing ticker WMT
# 2024-11-07 20:00:45,146, data_manager.py, 75, INFO, Processing ticker WMT
# 2024-11-07 20:00:45,146, data_manager.py, 111, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:45,146, data_manager.py, 111, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:45,558, data_manager.py, 85, INFO, Saving data for WMT by year
# 2024-11-07 20:00:45,558, data_manager.py, 85, INFO, Saving data for WMT by year
# 2024-11-07 20:00:47,151, data_manager.py, 75, INFO, Processing ticker DIS
# 2024-11-07 20:00:47,151, data_manager.py, 75, INFO, Processing ticker DIS
# 2024-11-07 20:00:47,151, data_manager.py, 111, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:47,151, data_manager.py, 111, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:47,533, data_manager.py, 85, INFO, Saving data for DIS by year
# 2024-11-07 20:00:47,533, data_manager.py, 85, INFO, Saving data for DIS by year
# 2024-11-07 20:00:49,196, data_manager.py, 75, INFO, Processing ticker WBD
# 2024-11-07 20:00:49,196, data_manager.py, 75, INFO, Processing ticker WBD
# 2024-11-07 20:00:49,196, data_manager.py, 111, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:49,196, data_manager.py, 111, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:49,454, data_manager.py, 85, INFO, Saving data for WBD by year
# 2024-11-07 20:00:49,454, data_manager.py, 85, INFO, Saving data for WBD by year
# 2024-11-07 20:00:50,713, data_manager.py, 75, INFO, Processing ticker WM
# 2024-11-07 20:00:50,713, data_manager.py, 75, INFO, Processing ticker WM
# 2024-11-07 20:00:50,713, data_manager.py, 111, INFO, Getting stock price data for WM from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:50,713, data_manager.py, 111, INFO, Getting stock price data for WM from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:50,997, data_manager.py, 85, INFO, Saving data for WM by year
# 2024-11-07 20:00:50,997, data_manager.py, 85, INFO, Saving data for WM by year
# 2024-11-07 20:00:52,654, data_manager.py, 75, INFO, Processing ticker WAT
# 2024-11-07 20:00:52,654, data_manager.py, 75, INFO, Processing ticker WAT
# 2024-11-07 20:00:52,654, data_manager.py, 111, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:52,654, data_manager.py, 111, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:52,921, data_manager.py, 85, INFO, Saving data for WAT by year
# 2024-11-07 20:00:52,921, data_manager.py, 85, INFO, Saving data for WAT by year
# 2024-11-07 20:00:54,472, data_manager.py, 75, INFO, Processing ticker WEC
# 2024-11-07 20:00:54,472, data_manager.py, 75, INFO, Processing ticker WEC
# 2024-11-07 20:00:54,472, data_manager.py, 111, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:54,472, data_manager.py, 111, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:54,799, data_manager.py, 85, INFO, Saving data for WEC by year
# 2024-11-07 20:00:54,799, data_manager.py, 85, INFO, Saving data for WEC by year
# 2024-11-07 20:00:56,364, data_manager.py, 75, INFO, Processing ticker WFC
# 2024-11-07 20:00:56,364, data_manager.py, 75, INFO, Processing ticker WFC
# 2024-11-07 20:00:56,364, data_manager.py, 111, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:56,364, data_manager.py, 111, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:56,709, data_manager.py, 85, INFO, Saving data for WFC by year
# 2024-11-07 20:00:56,709, data_manager.py, 85, INFO, Saving data for WFC by year
# 2024-11-07 20:00:58,327, data_manager.py, 75, INFO, Processing ticker WELL
# 2024-11-07 20:00:58,327, data_manager.py, 75, INFO, Processing ticker WELL
# 2024-11-07 20:00:58,327, data_manager.py, 111, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-11-07
# 2024-11-07 20:00:58,327, data_manager.py, 111, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:00:58,674, data_manager.py, 85, INFO, Saving data for WELL by year
# 2024-11-07 20:00:58,674, data_manager.py, 85, INFO, Saving data for WELL by year
# 2024-11-07 20:01:00,195, data_manager.py, 75, INFO, Processing ticker WST
# 2024-11-07 20:01:00,195, data_manager.py, 75, INFO, Processing ticker WST
# 2024-11-07 20:01:00,195, data_manager.py, 111, INFO, Getting stock price data for WST from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:00,195, data_manager.py, 111, INFO, Getting stock price data for WST from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:00,519, data_manager.py, 85, INFO, Saving data for WST by year
# 2024-11-07 20:01:00,519, data_manager.py, 85, INFO, Saving data for WST by year
# 2024-11-07 20:01:02,078, data_manager.py, 75, INFO, Processing ticker WDC
# 2024-11-07 20:01:02,078, data_manager.py, 75, INFO, Processing ticker WDC
# 2024-11-07 20:01:02,078, data_manager.py, 111, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:02,078, data_manager.py, 111, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:02,362, data_manager.py, 85, INFO, Saving data for WDC by year
# 2024-11-07 20:01:02,362, data_manager.py, 85, INFO, Saving data for WDC by year
# 2024-11-07 20:01:03,956, data_manager.py, 75, INFO, Processing ticker WRK
# 2024-11-07 20:01:03,956, data_manager.py, 75, INFO, Processing ticker WRK
# 2024-11-07 20:01:03,956, data_manager.py, 111, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:03,956, data_manager.py, 111, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-11-07 20:01:05,376, data_manager.py, 85, INFO, Saving data for WRK by year
# 2024-11-07 20:01:05,376, data_manager.py, 85, INFO, Saving data for WRK by year
# 2024-11-07 20:01:05,376, data_manager.py, 103, WARNING, No data found for WRK
# 2024-11-07 20:01:05,376, data_manager.py, 103, WARNING, No data found for WRK
# 2024-11-07 20:01:05,376, data_manager.py, 75, INFO, Processing ticker WY
# 2024-11-07 20:01:05,376, data_manager.py, 75, INFO, Processing ticker WY
# 2024-11-07 20:01:05,381, data_manager.py, 111, INFO, Getting stock price data for WY from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:05,381, data_manager.py, 111, INFO, Getting stock price data for WY from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:05,718, data_manager.py, 85, INFO, Saving data for WY by year
# 2024-11-07 20:01:05,718, data_manager.py, 85, INFO, Saving data for WY by year
# 2024-11-07 20:01:07,226, data_manager.py, 75, INFO, Processing ticker WHR
# 2024-11-07 20:01:07,226, data_manager.py, 75, INFO, Processing ticker WHR
# 2024-11-07 20:01:07,227, data_manager.py, 111, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:07,227, data_manager.py, 111, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:07,537, data_manager.py, 85, INFO, Saving data for WHR by year
# 2024-11-07 20:01:07,537, data_manager.py, 85, INFO, Saving data for WHR by year
# 2024-11-07 20:01:09,533, data_manager.py, 75, INFO, Processing ticker WMB
# 2024-11-07 20:01:09,533, data_manager.py, 75, INFO, Processing ticker WMB
# 2024-11-07 20:01:09,536, data_manager.py, 111, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:09,536, data_manager.py, 111, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:09,878, data_manager.py, 85, INFO, Saving data for WMB by year
# 2024-11-07 20:01:09,878, data_manager.py, 85, INFO, Saving data for WMB by year
# 2024-11-07 20:01:11,412, data_manager.py, 75, INFO, Processing ticker WTW
# 2024-11-07 20:01:11,412, data_manager.py, 75, INFO, Processing ticker WTW
# 2024-11-07 20:01:11,412, data_manager.py, 111, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:11,412, data_manager.py, 111, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:11,713, data_manager.py, 85, INFO, Saving data for WTW by year
# 2024-11-07 20:01:11,713, data_manager.py, 85, INFO, Saving data for WTW by year
# 2024-11-07 20:01:13,333, data_manager.py, 75, INFO, Processing ticker GWW
# 2024-11-07 20:01:13,333, data_manager.py, 75, INFO, Processing ticker GWW
# 2024-11-07 20:01:13,334, data_manager.py, 111, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:13,334, data_manager.py, 111, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:13,654, data_manager.py, 85, INFO, Saving data for GWW by year
# 2024-11-07 20:01:13,654, data_manager.py, 85, INFO, Saving data for GWW by year
# 2024-11-07 20:01:15,565, data_manager.py, 75, INFO, Processing ticker WYNN
# 2024-11-07 20:01:15,565, data_manager.py, 75, INFO, Processing ticker WYNN
# 2024-11-07 20:01:15,565, data_manager.py, 111, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:15,565, data_manager.py, 111, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:15,834, data_manager.py, 85, INFO, Saving data for WYNN by year
# 2024-11-07 20:01:15,834, data_manager.py, 85, INFO, Saving data for WYNN by year
# 2024-11-07 20:01:17,409, data_manager.py, 75, INFO, Processing ticker XEL
# 2024-11-07 20:01:17,409, data_manager.py, 75, INFO, Processing ticker XEL
# 2024-11-07 20:01:17,410, data_manager.py, 111, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:17,410, data_manager.py, 111, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:17,769, data_manager.py, 85, INFO, Saving data for XEL by year
# 2024-11-07 20:01:17,769, data_manager.py, 85, INFO, Saving data for XEL by year
# 2024-11-07 20:01:19,641, data_manager.py, 75, INFO, Processing ticker XYL
# 2024-11-07 20:01:19,641, data_manager.py, 75, INFO, Processing ticker XYL
# 2024-11-07 20:01:19,642, data_manager.py, 111, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:19,642, data_manager.py, 111, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:19,918, data_manager.py, 85, INFO, Saving data for XYL by year
# 2024-11-07 20:01:19,918, data_manager.py, 85, INFO, Saving data for XYL by year
# 2024-11-07 20:01:20,859, data_manager.py, 75, INFO, Processing ticker YUM
# 2024-11-07 20:01:20,859, data_manager.py, 75, INFO, Processing ticker YUM
# 2024-11-07 20:01:20,859, data_manager.py, 111, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:20,859, data_manager.py, 111, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:21,192, data_manager.py, 85, INFO, Saving data for YUM by year
# 2024-11-07 20:01:21,192, data_manager.py, 85, INFO, Saving data for YUM by year
# 2024-11-07 20:01:22,999, data_manager.py, 75, INFO, Processing ticker ZBRA
# 2024-11-07 20:01:22,999, data_manager.py, 75, INFO, Processing ticker ZBRA
# 2024-11-07 20:01:23,001, data_manager.py, 111, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:23,001, data_manager.py, 111, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:23,270, data_manager.py, 85, INFO, Saving data for ZBRA by year
# 2024-11-07 20:01:23,270, data_manager.py, 85, INFO, Saving data for ZBRA by year
# 2024-11-07 20:01:25,018, data_manager.py, 75, INFO, Processing ticker ZBH
# 2024-11-07 20:01:25,018, data_manager.py, 75, INFO, Processing ticker ZBH
# 2024-11-07 20:01:25,019, data_manager.py, 111, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:25,019, data_manager.py, 111, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:25,314, data_manager.py, 85, INFO, Saving data for ZBH by year
# 2024-11-07 20:01:25,314, data_manager.py, 85, INFO, Saving data for ZBH by year
# 2024-11-07 20:01:27,308, data_manager.py, 75, INFO, Processing ticker ZION
# 2024-11-07 20:01:27,308, data_manager.py, 75, INFO, Processing ticker ZION
# 2024-11-07 20:01:27,308, data_manager.py, 111, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:27,308, data_manager.py, 111, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:27,613, data_manager.py, 85, INFO, Saving data for ZION by year
# 2024-11-07 20:01:27,613, data_manager.py, 85, INFO, Saving data for ZION by year
# 2024-11-07 20:01:29,395, data_manager.py, 75, INFO, Processing ticker ZTS
# 2024-11-07 20:01:29,395, data_manager.py, 75, INFO, Processing ticker ZTS
# 2024-11-07 20:01:29,400, data_manager.py, 111, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-11-07
# 2024-11-07 20:01:29,400, data_manager.py, 111, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-11-07
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 20:01:29,601, data_manager.py, 85, INFO, Saving data for ZTS by year
# 2024-11-07 20:01:29,601, data_manager.py, 85, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-11-07 20:01:52,696, data_manager.py, 123, INFO, Creating features data.
# 2024-11-07 20:01:52,696, data_manager.py, 123, INFO, Creating features data.
# 2024-11-07 20:01:52,701, data_manager.py, 134, INFO, Loading price data from ../../05_src/data/prices/
# 2024-11-07 20:01:52,701, data_manager.py, 134, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\TazeenQ\.conda\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-11-07 20:01:54,762, data_manager.py, 142, INFO, Creating features
# 2024-11-07 20:01:54,762, data_manager.py, 142, INFO, Creating features
# c:\Users\TazeenQ\production\01_materials\labs\../../05_src\data_manager.py:144: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-11-07 20:01:54,862, data_manager.py, 160, INFO, Creating target
# 2024-11-07 20:01:54,862, data_manager.py, 160, INFO, Creating target
# c:\Users\TazeenQ\production\01_materials\labs\../../05_src\data_manager.py:161: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-11-07 20:01:54,998, data_manager.py, 170, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-11-07 20:01:54,998, data_manager.py, 170, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
